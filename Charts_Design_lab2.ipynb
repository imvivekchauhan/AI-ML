# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.array([9,10,20,32,48])
y1=np.array([19,30,10,52,68])
x=np.array([2,1,22,52,78])
y=np.array([3,7,9,32,68])

# %%
sizes=np.array([10,50,30,20,70])
plt.scatter(x1,y1,color="red")
plt.scatter(x,y,color="green",s=sizes, alpha=0.5)
plt.show()

# %%
plt.bar(x1,y1)
plt.show()

# %%
plt.barh(x1,y2)
plt.show()

# %%
plt.barh(x1,y1,height=6,color="y")
plt.show()

# %%
plt.bar(x1,y1,width=6,color="Green")
plt.show()

# %%
plt.hist(x1)
plt.show()

# %%
plt.pie(x)
plt.show()
plt.pie(y)
plt.show()

# %%
country_no=np.array([20,30,40,60,21])
country_name=["India","USA","UK","Turkey","Japan"]
plt.pie(country_no, labels=country_name,explode=[0.3,0,0,0,0],startangle=90,shadow=True)
plt.legend(title="Countries")
plt.show()
